# %%
#importing of libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from pandas.plotting import andrews_curves
from pandas.plotting import parallel_coordinates
sns.set(rc = {"figure.figsize": (8, 10)})

# %%
from google.colab import files
uploaded = files.upload()
data = pd.read_csv("iris.data")
data.head()
# Out:
#      <input type="file" id="files-7f69a67c-7f7e-4648-8195-c98ab4a46ff8" name="files[]" multiple disabled />
#      <output id="result-7f69a67c-7f7e-4648-8195-c98ab4a46ff8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.data to iris.data
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
print("Row, Col", data.shape)
# Out:
# Row, Col (149, 5)

# %%
data.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.info
# Out:
# <bound method DataFrame.info of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
data.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
data1 = data.copy()
#labelling the data
data1.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width",
               "category"]
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# **PAIR PLOT**

# %%
sns.pairplot(data=data1, hue='category')

# %%
data1["category"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: category, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
sns.countplot(x="category",data=data1)

# %%
pd.crosstab(data1["category"], columns="count", normalize=True)
# Out:
# col_0               count
# category
# Iris-setosa      0.328859
# Iris-versicolor  0.335570
# Iris-virginica   0.335570

# %% [markdown]
# **BOX PLOT**

# %%
# all attributes vs category
fig, (axis1,axis2,axis3, axis4) = plt.subplots(1,4,figsize=(16,11))

sns.boxplot(x="category", y="sepal_length", data=data1, ax=axis1)
axis1.set_title("category vs sepal_length")

sns.boxplot(x="category", y="sepal_width", data=data1, ax=axis2)
axis2.set_title("category vs sepal_width")

sns.boxplot(x="category", y="petal_length", data=data1, ax=axis3)
axis3.set_title("category vs petal_length")

sns.boxplot(x="category", y="petal_width", data=data1, ax=axis4)
axis4.set_title("category vs petal_width")
# Out:
# Text(0.5, 1.0, 'category vs petal_width')

# %% [markdown]
# **VIOLIN PLOT**

# %%
# all attributes vs category
fig, (axis1,axis2,axis3, axis4) = plt.subplots(1,4,figsize=(16,11))

sns.violinplot(x="category", y="sepal_length", data=data1, ax=axis1)
axis1.set_title("category vs sepal_length")

sns.violinplot(x="category", y="sepal_width", data=data1, ax=axis2)
axis2.set_title("category vs sepal_width")

sns.violinplot(x="category", y="petal_length", data=data1, ax=axis3)
axis3.set_title("category vs petal_length")

sns.violinplot(x="category", y="petal_width", data=data1, ax=axis4)
axis4.set_title("category vs petal_width")
# Out:
# Text(0.5, 1.0, 'category vs petal_width')

# %% [markdown]
# #**In Pandas use Andrews Curves to plot and visualize data structure**.
# #This useful for detecting outliers in times series data.
# #Use colormap to change the color of the

# %%
andrews_curves(data1, "category",colormap='rainbow')
plt.show()

# %% [markdown]
# **PARALLEL COORDINATES**
#         is a plotting technique for plotting multivariate data. Parallel coordinates allows one to see clusters in data and to estimate. other statistics visually. Using parallel coordinates points are represented as connected line segments. Each vertical line represents one attribute. One set of connected line segments represents one data point. Points that tend to cluster will appear closer together.

# %%
plt.figure()
parallel_coordinates(data1,"category")

# %% [markdown]
# **layout and targeting multiple axes**
# The layout of subplots can be specified by the layout keyword. It can accept (rows, columns). The layout keyword can be used in hist and boxplot also. If the input is invalid, a ValueError will be raised.

# %% [markdown]
# **JOIN PLOT**

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=data1, size=5,ratio=5, kind='hex',color='green')
sns.jointplot(x="petal_length", y="petal_width", data=data1, size=5,ratio=5, kind='hex',color='red')
plt.show()
sns.jointplot(x = 'sepal_length', y = 'sepal_width', data = data1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **STRIP PLOT**

# %%
fig, (axis1,axis2,axis3, axis4) = plt.subplots(1,4,figsize=(16,11))

sns.stripplot(x="category", y="sepal_length", data=data1, ax=axis1)
axis1.set_title("category vs sepal_length")

sns.stripplot(x="category", y="sepal_width", data=data1, ax=axis2)
axis2.set_title("category vs sepal_width")

sns.stripplot(x="category", y="petal_length", data=data1, ax=axis3)
axis3.set_title("category vs petal_length")

sns.stripplot(x="category", y="petal_width", data=data1, ax=axis4)
axis4.set_title("category vs petal_width")
# Out:
# Text(0.5, 1.0, 'category vs petal_width')

# %% [markdown]
# **SWAM PLOT**

# %%
fig, (axis1,axis2,axis3, axis4) = plt.subplots(1,4,figsize=(16,11))

sns.swarmplot(x="category", y="sepal_length", data=data1, ax=axis1)
axis1.set_title("category vs sepal_length")

sns.swarmplot(x="category", y="sepal_width", data=data1, ax=axis2)
axis2.set_title("category vs sepal_width")

sns.swarmplot(x="category", y="petal_length", data=data1, ax=axis3)
axis3.set_title("category vs petal_length")

sns.swarmplot(x="category", y="petal_width", data=data1, ax=axis4)
axis4.set_title("category vs petal_width")
# Out:
# Text(0.5, 1.0, 'category vs petal_width')

# %% [markdown]
# **lmplot()**
# function in seaborn
# Seaborn’s lmplot is a 2D scatterplot with an optional overlaid regression line. Logistic regression for binary classification is also supported with lmplot . It is intended as a convenient interface to fit regression models across conditional subsets of a dataset.

# %%
sns.lmplot(x = 'sepal_length', y = 'sepal_width', data = data1, hue = 'category', col = 'category')

# %% [markdown]
# **STACKED BAR**

# %%
data1.plot.bar(stacked=True, figsize=(15,10));

# %% [markdown]
# **SUB PLOT**

# %%
data1.plot(subplots=True, figsize=(10, 10));

# %%
X=data1.iloc[:,:4]
Y=data1["category"]
train_x, test_x, train_y, test_y = train_test_split(X,Y, test_size=0.3)

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
log = LogisticRegression(max_iter=1200,solver="lbfgs")
log.fit(train_x, train_y)
pred_lr = log.predict(test_x)
acc_lr = accuracy_score(test_y, pred_lr)
print(f"Accuracy of Logistic Regression Model: {round(acc_lr*100, 2)}%")
# Out:
# Accuracy of Logistic Regression Model: 95.56%

# %% [markdown]
# **DECISION TREE MODEL**

# %%
d_tree = DecisionTreeClassifier()
d_tree.fit(X_train, Y_train)
pred_dtree = d_tree.predict(X_test)
acc_dtree = accuracy_score(Y_test, pred_dtree)
print(f"Accuracy of Decision Tree Model: {round(acc_lr*100, 2)}%")
# Out:
# Accuracy of Decision Tree Model: 93.33%

# %% [markdown]
# **KNN**

# %%
KNN = KNeighborsClassifier(n_neighbors=5)
KNN.fit(train_x, train_y)
pred_knn = KNN.predict(test_x)
acc_knn = accuracy_score(test_y, pred_knn)
print(f"Accuracy of KNN Model: {round(acc_knn*100, 2)}%")
# Out:
# Accuracy of KNN Model: 97.78%

# %% [markdown]
# **SVM MODEL**

# %%
svc = SVC()
svc.fit(train_x, train_y)
pred_svc = svc.predict(test_x)
acc_svc = accuracy_score(test_y, pred_svc)
print(f"Accuracy of SVC Model: {round(acc_knn*100, 2)}%")
# Out:
# Accuracy of SVC Model: 97.78%

# %% [markdown]
# **XG BOOST**

# %%
# Improving Accuracy using Boosting in Ml
from xgboost import XGBClassifier
import sklearn.metrics as metrics

xgb_classifier = XGBClassifier()
xgb_classifier.fit(train_x,train_y)
y_pred_xgb = xgb_classifier.predict(test_x)

acc_svc_xgb = metrics.accuracy_score(test_y, y_pred_xgb)
print(f"Accuracy after Boosting: {acc_svc_xgb*100}%")
# Out:
# Accuracy after Boosting: 93.33333333333333%
